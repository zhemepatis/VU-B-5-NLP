# %% [markdown]
# #### 1. Pateiktam sakiniui pateikite priklausomybių gramatikos medį, pakeisdami jo fono ir teksto spalvas (spalvas parinkite savo nuožiūra). Atspausdinkite mazgus ir priklausomybių žymas.

# %%
import spacy
from spacy import displacy

text = 'The students exam scores were all fantastic'
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)

opt = {
    "bg": "#333",
    "color": "#fff",
    "compact": True,
}
displacy.render(doc, style="dep", jupyter=True, options=opt)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0067ba98888348a9a49d70e9546aeabc-0" class="displacy" width="1100" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #fff; background: #333; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">students</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
# ...

# %% [markdown]
# #### 2. Tam pačiam sakiniui pateikite priklausomybių gramatikos medį parinkdami kompaktišką vaizdavimo režimą bei atspausdindami lemas atskiroje eilutėje po sakinio tokenais.

# %%
opt = {
    "bg": "#592250",
    "color": "#F2B544",
    "compact": True,
    "add_lemma": True
}
displacy.render(doc, style="dep", jupyter=True, options=opt)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4bd0a7f9a1af4c3f87f5e71f66d56087-0" class="displacy" width="1100" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #F2B544; background: #592250; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">students</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="200">student</tspan>
# ...

# %% [markdown]
# #### 3. Pateiktam sakiniui pateikite priklausomybių gramatikos medį

# %%
nlp = spacy.load("lt_core_news_sm")
text = "Vaikas eina namo" # šioje vietoje lietuvių kalbos modelis nesupranta, kad "namo" yra būdvardis
doc = nlp(text)

opt = {
    "bg": "#333",
    "color": "#fff",
    "compact": True
}
displacy.render(doc, style="dep", jupyter=True, options=opt)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="lt" id="6febf969452d4601a277d3f4b4bdba74-0" class="displacy" width="500" height="212.0" direction="ltr" style="max-width: none; height: 212.0px; color: #fff; background: #333; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Vaikas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">eina</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
# ...

# %% [markdown]
# #### 4. Pateiktam sakiniui pateikite priklausomybių gramatikos medį, pakeisdami jo fono ir teksto spalvas (spalvas parinkite savo nuožiūra). Atskiroje eilutėje po sakinio tokenais atspausdinkite lemas. Atspausdinkite mazgus ir priklausomybių žymas.¶

# %%
nlp = spacy.load("lt_core_news_sm")
text = "Žmogus be mokslo kaip namai be langų"
doc = nlp(text)

opt = {
    "bg": "#333",
    "color": "#fff",
    "compact": True,
    "add_lemma": True
}
displacy.render(doc, style="dep", jupyter=True, options=opt)
for token in doc:
    print(f"{token.text:{15}} {token.dep_:{15}} {token.head.text:{15}} {token.pos_:{15}} {[child for child in token.children]}")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="lt" id="5d4d523de7a04426bfc44ade8b6f1039-0" class="displacy" width="1100" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #fff; background: #333; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Žmogus</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="50">žmogus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">be</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="200">be</tspan>
# ...

# %% [markdown]
# #### 5. Iš duoto tekstinio failo "Tekstas.txt" atrinkite tik tuos sakinius, kuriuose yra veiksmažodžiai. Kiekvienam sakiniui, kuriame yra veiksmažodis, pavaizduokite gramatinį priklausomybių medį (dependency tree).

# %%
with open("data/06_data.txt") as file:
    text = file.read()

nlp = spacy.load('en_core_web_sm')
doc = nlp(text)

target_sentences = []
for sentence in doc.sents:
    for word in sentence:
        if word.pos_ == "VERB":
            target_sentences.append(sentence)
            break

for sentence in target_sentences:
    sentence_doc = nlp(sentence.__str__().replace("\n", "").replace(".", ""))
    opt = {
    "bg": "#333",
    "color": "#fff",
    "compact": True,
    "add_lemma": True
    }
    displacy.render(sentence_doc, style="dep", jupyter=True, options=opt)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1b1e9e02f267435aac125bc467ef27de-0" class="displacy" width="1100" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #fff; background: #333; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="50">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">long</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="200">long</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADJ</tspan>
# ...

# %% [markdown]
# #### 6. Nustatykite kiekvieno sakinio galvą (angl. head) ir jos vaikus (angl. children)

# %%
nlp = spacy.load("lt_core_news_sm")
text = "Vaikai žaidžia parke. Jis skaito naują knygą. Saulė šviečia ryškiai."
doc = nlp(text)

for sent in doc.sents:
    sent_doc = nlp(sent.__str__().replace("\n", "").replace(".", ""))

    opt = {
    "bg": "#333",
    "color": "#fff",
    "compact": True,
    "add_lemma": True
    }
    displacy.render(sent_doc, style="dep", jupyter=True, options=opt)

    result = []
    for token in sent_doc:
        result.append(f"{token.head.text:{15}} {[child for child in token.head.children]}")

    head_set = set(result)
    for item in head_set:
        print(item)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="lt" id="e2f7c718d9e14e23a66ccaffaecbb170-0" class="displacy" width="500" height="212.0" direction="ltr" style="max-width: none; height: 212.0px; color: #fff; background: #333; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Vaikai</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="50">vaikas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="122.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">žaidžia</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="200">žaisti</tspan>
# ...
